# %%
print("My Name is " +Nama+ ", My StudentID is " +StudentID+ ", majoring in " +Major+ ", And Im batch "+str(Batch))
# Out:
# My Name is Deni Kusuma, My StudentID is 001201900095, majoring in Information Technology, And Im batch 2019

# %%
Nama = "Deni Kusuma"
StudentID = "001201900095"
Major = "Information Technology"
Batch = 2019
