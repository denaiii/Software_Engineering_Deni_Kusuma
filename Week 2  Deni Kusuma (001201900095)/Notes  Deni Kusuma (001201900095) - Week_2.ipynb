# %%
print("Hello World")
# Out:
# Hello World

# %%
# for comment
a = 10 #integer
b = 3.14 #float
c = "T" #String
d = "Deni"
e = "Software Engineering"
f = True #boolean
g = False #boolean
h = [] #List
i = [1,2,3] #List
j = {} #Dictionary
k = () #Tuple

# %%
#Print
print(e)
print(2+5*2)
print('hello world')
# Out:
# Software Engineering
# 12
# hello world

# %%
#concatination
print("Hewwooo nama ku adalah " +nama) 
print("hewoo nama ku adalah {}".format(nama))
print("hewooo nama ku adalah {}".format("Deni"))
# Out:
# Hewwooo nama ku adalah deni
# hewoo nama ku adalah deni
# hewooo nama ku adalah Deni

# %%
nama = 'deni'
umur = 20
tinggal = "jakarta"

# %%
List1 =[0, 1, "deni", True, ['deni', 8]]

# %%
nama = input()
# Out:
# deni

# %%
print("Hewoo nama ku adalah {}, umurku {}".format(nama, umur))
# Out:
# Hewoo nama ku adalah deni, umurku 20

# %%
print("Hewoo nama ku adalah " +nama+ ", umurku "+str(umur))
# Out:
# Hewoo nama ku adalah deni, umurku 20

# %%
print("Hewoo nama ku adalah {}, umurku {}, tinggal di {}".format(nama, umur, tinggal))
# Out:
# Hewoo nama ku adalah deni, umurku 20, tinggal di jakarta

# %%
#operator
#import.math
a = 10 
b = 10
#if else
#conditional statement
a == b #jika a sama dengan b
a!= b #jika a tidak sama dengan b
a<b
a<=b
a>b
a>=b
#True and True
#False or True
a + b
a - b
a * b
a / b # 10 / 10 = 1.0 > float division
a // b # 10 // 10 = 1 > int division
a ** b # 10 ^ 10 = 100
a % b 
a ** (1/2) #akar variable a, dimana a = 10
math.sqrt(a) #akar variable a
math.sin(a)
math.cos(a)
math.tan(a)
math.tanh(a)
math.sinh(a)
math.cosh(a)
math.log(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-0e643fb7b609> in <module>()
#      21 a % b
#      22 a ** (1/2) #akar variable a, dimana a = 10
# ---> 23 math.sqrt(a) #akar variable a
#      24 math.sin(a)
#      25 math.cos(a)
#
# NameError: name 'math' is not defined

# %%
if a == 10:
  print ('a lbih bsr 10')
elif a > 10:
  print ('a lbih bsr dari10')
else:
  print('a kkrng dari 10')
print('buat diluar if')
# Out:
# a lbih bsr 10
# buat diluar if
